# %%
import os
import csv
import pandas as pd
import numpy as np


happy2015_df = pd.read_csv('2015.csv')
happy2016_df = pd.read_csv('2016.csv')
happy2017_df = pd.read_csv('2017.csv')
happy2018_df = pd.read_csv('2018.csv')
happy2019_df = pd.read_csv('2019.csv')
happy2016_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
#do we want to start by renaming all the columns? 
country_rank_trust_2015 = happy2015_df[["Country", "Happiness Rank","Trust (Government Corruption)"]]
country_rank_trust_2015 = country_rank_trust_2015.set_index("Country")
country_rank_trust_2015.head()
# Out:
#              Happiness Rank  Trust (Government Corruption)
# Country
# Switzerland               1                        0.41978
# Iceland                   2                        0.14145
# Denmark                   3                        0.48357
# Norway                    4                        0.36503
# Canada                    5                        0.32957

# %%
#merging dataframes 2015 and 2016, x and y respectively
happy_2015and2016 = happy2015_df.merge(happy2016_df, on="Country")
happy_2015and2016.head()
# Out:
#        Country        Region_x  Happiness Rank_x  Happiness Score_x  \
# 0  Switzerland  Western Europe                 1              7.587
# 1      Iceland  Western Europe                 2              7.561
# 2      Denmark  Western Europe                 3              7.527
# 3       Norway  Western Europe                 4              7.522
# 4       Canada   North America                 5              7.427
#
#    Standard Error  Economy (GDP per Capita)_x  Family_x  \
# 0         0.03411                     1.39651   1.34951
# 1         0.04884                     1.30232   1.40223
# 2         0.03328                     1.32548   1.36058
# 3         0.03880                     1.45900   1.33095
# 4         0.03553                     1.32629   1.32261
#
#    Health (Life Expectancy)_x  Freedom_x  Trust (Government Corruption)_x  \
# 0                     0.94143    0.66557                          0.41978
# ...
